# %%
from oving_uke05 import MyBinaryNode

# %%
args = "+ + * 4 5 6 7".split()
tree = MyBinaryNode(None)
tree.parse_prefix_input(args)

# %%
tree.traverse_inorder()
# Out:
# (((4*5)+6)+7)

# %%
tree.traverse_postfix()
# Out:
# 4 5 * 6 + 7 +

# %%
print(tree.compute())
# Out:
# 33

# %%
viz = tree.visualize()
